# %% [markdown]
# ##### Script that takes the object masks as input, converts them to features vectors using a pre-trained Res2Net model, and then cluster them using K-Means. The clusters are then saved in a new folder

# %%
import torch

import sys
sys.path.append("lib")
from Res2Net.res2net import Res2Net, res2net50

model = res2net50(pretrained=True)

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f'Using {device} for inference')
# Out:
# Using cuda for inference

# %%
from torchvision import transforms
from PIL import Image

# Load list of folders in the folder
# Folder is in format MOVE_neighbourhood_full_masks
folder_path = 'res/dataset/centrum_west_full/masked_extracted/'

# %%
def get_array(img, model, device):
    # Apply transformations
    transform = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                  std=[0.229, 0.224, 0.225]),
    ])

    model.eval()
    model.to(device)

    img = transform(img).unsqueeze(0).to(device)
    output = model(img)

    return output

# %%
import os

# Create a dictionary which links each left and right image with their panorama id, the future array it will be converted to,
# and the label they will get after the clustering. This is a way to not lose the information of the original image
data = {}

# The folder contains a list of folders, each one containing the masks for back, front, left and right images
# We are interested in just the left and right ones
# Ignore the .DS_Store file if it exists
imgs = ['/left.png', '/right.png']

panoramas = os.listdir(folder_path)

test_panoramas = panoramas[:30]

# %%
for panorama_folder in test_panoramas:
    # Create a sub-dictionary for the pano ID
    data[panorama_folder] = {}

    if panorama_folder != '.DS_Store':
        for lr in ['left', 'right']:
            # Create a sub-dictionary for the left/right image
            data[panorama_folder][lr] = {'array': None, 'label': None}
            # Load list of files in the folder
            # File is in format neighbourhood/panorama_folder/image
            file_path = folder_path + panorama_folder + f'/{lr}.png'

            # Get the feature vector
            img = Image.open(file_path)
            array = get_array(img, model, device)

            # Add the feature vector to the dictionary
            # ToDo: distinguish multiple objects in the images
            data[panorama_folder][lr]['array'] = array

# %%
# Save data as json file, making sure to serialize the numpy arrays
import json
import numpy as np

with open('res/dataset/centrum_west_full/masked_extracted/data.json', 'w') as fp:
    json.dump(data, fp, default=lambda o: o.tolist())

# %%
# Take a random array from the data and print its shape
import random

random_pano = random.choice(list(data.keys()))
random_lr = random.choice(list(data[random_pano].keys()))
print(data[random_pano][random_lr]['array'])
# Out:
# [[-0.789955735206604, -0.008090628311038017, -0.08159809559583664, -0.30156582593917847, 0.15623138844966888, -0.4778293967247009, -0.43764495849609375, -0.8523749113082886, -0.7960759401321411, 0.4071865677833557, 0.6298608183860779, -0.6983688473701477, 0.39087432622909546, -0.262079119682312, 1.0405038595199585, -0.47129496932029724, -0.7785969972610474, 0.7000814080238342, -0.1160641759634018, -0.9445639252662659, -0.46862611174583435, -0.08714693039655685, -0.24692095816135406, 0.20641455054283142, -0.22553864121437073, -0.9834144711494446, -0.4466533660888672, -0.9979915022850037, 0.33518916368484497, 0.3323114216327667, -0.8450190424919128, -0.5648680925369263, -1.158013939857483, 0.54220050573349, 1.2035659551620483, -0.2932915985584259, 0.19666869938373566, -0.14480654895305634, 0.3102022409439087, 0.023250890895724297, -0.7191408276557922, 1.411402940750122, -0.1108783483505249, -0.44602251052856445, 0.29208821058273315, 0.7119518518447876, -0.7471349835395813, 0.11746872216463089, 0.08749661594629288, 0.12558335065841675, -0.3518845736980438, -0.6306023001670837, 0.8714460134506226, 0.1942751258611679, 0.691838800907135, -0.08310265094041824, 0.31994500756263733, -0.8079366087913513, 0.07253405451774597, 1.1698564291000366, 0.9423966407775879, -0.564525306224823, -0.6019266843795776, -0.08031176775693893, 0.9318870306015015, -0.046579986810684204, -0.047889020293951035, 0.4798351228237152, -0.22778421640396118, -0.7104073166847229, -0.7338122725486755, -0.5413923263549805, -0.22299471497535706, -0.054016001522541046, -0.7233327031135559, 0.11120323091745377, -0.010363960638642311, 0.47727516293525696, -0.751204788684845, -0.4290640354156494, -0.9302582740783691, 0.4968952536582947, -1.1579182147979736, -1.1345964670181274, -0.4490283131599426, -0.16206645965576172, -0.5970715880393982, -1.3741220235824585, -0.342725545167923, 0.44401291012763977, -0.35059458017349243, -0.448690801858902, 1.7608648538589478, 0.8375760912895203, -0.12761974334716797, 0.36016547679901123, 0.24042007327079773, -0.9648018479347229, -0.8150311708450317, -1.3480870723724365, -0.30053821206092834, -0.5261431336402893, -1.0938336849212646, 0.08395756781101227, -1.4572259187698364, -1.5323785543441772, -0.703345775604248, -0.19022426009178162, -0.49497565627098083, -0.17904570698738098, 0.46611225605010986, 0.942153811454773, -0.09856578707695007, -0.39480242133140564, -1.1484601497650146, -0.03698176518082619, -0.1514609009027481, -0.5692408680915833, -0.5219929218292236, 0.8407052755355835, -0.34494343400001526, -1.0555309057235718, -0.7260891199111938, -0.45143038034439087, -0.9113297462463379, -1.1737160682678223, -0.23661109805107117, 0.1818978190422058, 0.005163826048374176, 0.9006363153457642, 0.9298847913742065, -0.4708162546157837, 0.31681594252586365, -1.8998318910598755, -0.28068462014198303, -0.617278516292572, -1.3924362659454346, -0.618821382522583, -0.3533647656440735, -0.2657712996006012, -1.1000696420669556, 0.3461039364337921, -0.6526840329170227, 0.06494082510471344, -0.6882093548774719, 0.2578813433647156, 0.41768842935562134, 0.003506982699036598, -0.31527575850486755, 1.0172443389892578, -0.2271079272031784, -0.06452539563179016, -1.039241075515747, -0.36172550916671753, -0.6000113487243652, -0.040817469358444214, -0.604186475276947, -1.123067021369934, -1.2015403509140015, -0.4205404222011566, -1.0184708833694458, 0.5203976631164551, -0.29445797204971313, 0.7365323901176453, -0.10508008301258087, -0.8538819551467896, -0.8480858206748962, -0.7909219264984131, 0.3812708258628845, -0.19392463564872742, 0.07031664252281189, -0.06228090077638626, 0.390068382024765, 0.2664813697338104, 1.3902981281280518, -1.125471830368042, -0.7706280946731567, -0.8962849974632263, -0.15726467967033386, -0.028162743896245956, -0.5979364514350891, -0.7790482640266418, 0.18703055381774902, 0.21084147691726685, -0.022991415113210678, 0.03097528964281082, -0.443688303232193, -1.229443073272705, -0.4870069921016693, -0.19147001206874847, -0.78924 ...

# %%
# Clustering step
import sklearn
from sklearn.cluster import KMeans

# Load the data.json file where the feature vectors are stored
with open('res/dataset/centrum_west_full/masked_extracted/data.json') as json_file:
    data = json.load(json_file)

# Create a list of all the feature vectors
feature_vectors = []
for panorama in data:
    for lr in ['left', 'right']:
        feature_vectors.append(data[panorama][lr]['array'])

# Make the feature_vectors list a list of numpy arrays with dim 2
feature_vectors = np.array(feature_vectors)
feature_vectors = feature_vectors.reshape(feature_vectors.shape[0], -1)


# Apply KMeans clustering
clusters = 6
kmeans = KMeans(n_clusters=clusters, random_state=0).fit(feature_vectors)
labels = kmeans.predict(feature_vectors)
# Out:
# /home/andrealombardo/miniconda3/envs/sidewalk/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Add the labels to the data dictionary
for panorama in data:
    for lr in ['left', 'right']:
        data[panorama][lr]['label'] = labels[0]
        labels = labels[1:]

# Save data as json file, making sure to serialize the numpy arrays
with open('res/dataset/centrum_west_full/masked_extracted/data.json', 'w') as fp:
    json.dump(data, fp, default=lambda o: o.tolist())

# %%
# Make a folder in res/dataset/centrum_west_full/masked_extracted/ for each label
# Copy the images in the corresponding label folder
import shutil

for label in range(clusters):
    label_folder_path = f'res/dataset/centrum_west_full/masked_extracted/label_{label}/'
    if not os.path.exists(label_folder_path):
        os.makedirs(label_folder_path)

# %%
nmbr = 0
for panorama in data:
    for lr in ['left', 'right']:
        label = data[panorama][lr]['label']
        print('Panorama: ', panorama, 'LR: ', lr, 'Label: ', label)
        folder_path = f'res/dataset/centrum_west_full/masked_extracted/label_{label}/'
        file_path = folder_path + f'{lr}_{nmbr}.png'
        print('File path: ', file_path)
        shutil.copyfile(f'res/dataset/centrum_west_full/masked_extracted/{panorama}/{lr}.png', file_path)
        nmbr += 1
# Out:
# Panorama:  TMX7316010203-002538_pano_0000_003920 LR:  left Label:  1
# File path:  res/dataset/centrum_west_full/masked_extracted/label_1/left_0.png
# Panorama:  TMX7316010203-002538_pano_0000_003920 LR:  right Label:  2
# File path:  res/dataset/centrum_west_full/masked_extracted/label_2/right_1.png
# Panorama:  TMX7316010203-002050_pano_0001_001277 LR:  left Label:  1
# File path:  res/dataset/centrum_west_full/masked_extracted/label_1/left_2.png
# Panorama:  TMX7316010203-002050_pano_0001_001277 LR:  right Label:  0
# File path:  res/dataset/centrum_west_full/masked_extracted/label_0/right_3.png
# Panorama:  TMX7316010203-002620_pano_0002_000328 LR:  left Label:  3
# File path:  res/dataset/centrum_west_full/masked_extracted/label_3/left_4.png
# Panorama:  TMX7316010203-002620_pano_0002_000328 LR:  right Label:  3
# File path:  res/dataset/centrum_west_full/masked_extracted/label_3/right_5.png
# Panorama:  TMX7316010203-002548_pano_0000_000963 LR:  left Label:  4
# File path:  res/dataset/centrum_west_full/masked_extracted/label_4/left_6.png
# Panorama:  TMX7316010203-002548_pano_0000_000963 LR:  right Label:  0
# File path:  res/dataset/centrum_west_full/masked_extracted/label_0/right_7.png
# Panorama:  TMX7316010203-002365_pano_0001_000044 LR:  left Label:  4
# File path:  res/dataset/centrum_west_full/masked_extracted/label_4/left_8.png
# Panorama:  TMX7316010203-002365_pano_0001_000044 LR:  right Label:  0
# File path:  res/dataset/centrum_west_full/masked_extracted/label_0/right_9.png
# Panorama:  TMX7316010203-002549_pano_0000_002168 LR:  left Label:  4
# File path:  res/dataset/centrum_west_full/masked_extracted/label_4/left_10.png
# Panorama:  TMX7316010203-002549_pano_0000_002168 LR:  right Label:  4
# File path:  res/dataset/centrum_west_full/masked_extracted/label_4/right_11.png
# Panorama:  TMX7316010203-002045_pano_0001_000915 LR:  left Label:  1
# File path:  res/dataset/centrum_west_full/masked_extracted/label_1/left_12.png
# Panorama:  TMX7316010203-002045_pano_0001_000915 LR:  right Label:  1
# File path:  res/dataset/centrum_west_full/masked_extracted/label_1/right_13.png
# Panorama:  TMX7316010203-002538_pano_0000_003027 LR:  left Label:  2
# File path:  res/dataset/centrum_west_full/masked_extracted/label_2/left_14.png
# Panorama:  TMX7316010203-002538_pano_0000_003027 LR:  right Label:  3
# File path:  res/dataset/centrum_west_full/masked_extracted/label_3/right_15.png
# Panorama:  TMX7316010203-002310_pano_0000_002271 LR:  left Label:  1
# File path:  res/dataset/centrum_west_full/masked_extracted/label_1/left_16.png
# Panorama:  TMX7316010203-002310_pano_0000_002271 LR:  right Label:  1
# File path:  res/dataset/centrum_west_full/masked_extracted/label_1/right_17.png
# Panorama:  TMX7316010203-002549_pano_0000_000555 LR:  left Label:  1
# File path:  res/dataset/centrum_west_full/masked_extracted/label_1/left_18.png
# Panorama:  TMX7316010203-002549_pano_0000_000555 LR:  right Label:  1
# File path:  res/dataset/centrum_west_full/masked_extracted/label_1/right_19.png
# Panorama:  TMX7316010203-002365_pano_0003_000006 LR:  left Label:  0
# File path:  res/dataset/centrum_west_full/masked_extracted/label_0/left_20.png
# Panorama:  TMX7316010203-002365_pano_0003_000006 LR:  right Label:  4
# File path:  res/dataset/centrum_west_full/masked_extracted/label_4/right_21.png
# Panorama:  TMX7316010203-002569_pano_0000_002300 LR:  left Label:  4
# File path:  res/dataset/centrum_west_full/masked_extracted/label_4/left_22.png
# Panorama:  TMX7316010203-002569_pano_0000_002300 LR:  right Label:  4
# File path:  res/dataset/centrum_west_full/masked_extracted/label_4/right_23.png
# Panorama:  TMX7316010203-002037_pano_0000_001429 LR:  left Label:  1
# File path:  res/dataset/centrum_west_full/masked_extracted/label_1/left_24.png
# Panorama:  TMX7316010203-002037_pano_0000_001429 LR:  right Label:  1
# File path:  res/dataset/centrum_west_full/masked_extracted/label_1/right_25.png
# Panorama:  TMX7316010203-002620_pano_0002_000220 LR:  left Label:  0
# File path:  res/dataset/centrum_west_full/masked_extracted/label_0/left_26.png
# Panorama:  TMX7316010203-002620_pano_0002_000220 LR:  right Label:  0
# File path:  res/dataset/centrum_west_full/masked_extracted/label_0/right_27.png
# Panorama:  TMX7316010203-002032_pano_0000_001605 LR:  left Label:  0
# File path:  res/dataset/centrum_west_full/masked_extracted/label_0/left_28.png
# Panorama:  TMX7316010203-002032_pano_0000_001605 LR:  right Label:  0
# File path:  res/dataset/centrum_west_full/masked_extracted/label_0/right_29.png
# Panorama:  TMX7316010203-002549_pano_0000_002154 LR:  left Label:  5
# File path:  res/dataset/centrum_west_full/masked_extracted/label_5/left_30.png
# Panorama:  TMX7316010203-002549_pano_0000_002154 LR:  right Label:  1
# File path:  res/dataset/centrum_west_full/masked_extracted/label_1/right_31.png
# Panorama:  TMX7316010203-002037_pano_0001_000012 LR:  left Label:  3
# File path:  res/dataset/centrum_west_full/masked_extracted/label_3/left_32.png
# Panorama:  TMX7316010203-002037_pano_0001_000012 LR:  right Label:  3
# File path:  res/dataset/centrum_west_full/masked_extracted/label_3/right_33.png
# Panorama:  TMX7316010203-002310_pano_0000_001510 LR:  left Label:  4
# File path:  res/dataset/centrum_west_full/masked_extracted/label_4/left_34.png
# Panorama:  TMX7316010203-002310_pano_0000_001510 LR:  right Label:  0
# File path:  res/dataset/centrum_west_full/masked_extracted/label_0/right_35.png
# Panorama:  TMX7316010203-002859_pano_0000_000163 LR:  left Label:  1
# File path:  res/dataset/centrum_west_full/masked_extracted/label_1/left_36.png
# Panorama:  TMX7316010203-002859_pano_0000_000163 LR:  right Label:  2
# File path:  res/dataset/centrum_west_full/masked_extracted/label_2/right_37.png
# Panorama:  TMX7316010203-002050_pano_0001_001403 LR:  left Label:  3
# File path:  res/dataset/centrum_west_full/masked_extracted/label_3/left_38.png
# Panorama:  TMX7316010203-002050_pano_0001_001403 LR:  right Label:  1
# File path:  res/dataset/centrum_west_full/masked_extracted/label_1/right_39.png
# Panorama:  TMX7316010203-002549_pano_0000_001431 LR:  left Label:  4
# File path:  res/dataset/centrum_west_full/masked_extracted/label_4/left_40.png
# Panorama:  TMX7316010203-002549_pano_0000_001431 LR:  right Label:  0
# File path:  res/dataset/centrum_west_full/masked_extracted/label_0/right_41.png
# Panorama:  TMX7316010203-002924_pano_0006_000000 LR:  left Label:  4
# File path:  res/dataset/centrum_west_full/masked_extracted/label_4/left_42.png
# Panorama:  TMX7316010203-002924_pano_0006_000000 LR:  right Label:  1
# File path:  res/dataset/centrum_west_full/masked_extracted/label_1/right_43.png
# Panorama:  TMX7316010203-002620_pano_0007_000071 LR:  left Label:  3
# File path:  res/dataset/centrum_west_full/masked_extracted/label_3/left_44.png
# Panorama:  TMX7316010203-002620_pano_0007_000071 LR:  right Label:  1
# File path:  res/dataset/centrum_west_full/masked_extracted/label_1/right_45.png
# Panorama:  TMX7316010203-002538_pano_0000_003595 LR:  left Label:  1
# File path:  res/dataset/centrum_west_full/masked_extracted/label_1/left_46.png
# Panorama:  TMX7316010203-002538_pano_0000_003595 LR:  right Label:  1
# File path:  res/dataset/centrum_west_full/masked_extracted/label_1/right_47.png
# Panorama:  TMX7316010203-002050_pano_0001_002770 LR:  left Label:  3
# File path:  res/dataset/centrum_west_full/masked_extracted/label_3/left_48.png
# Panorama:  TMX7316010203-002050_pano_0001_002770 LR:  right Label:  1
# File path:  res/dataset/centrum_west_full/masked_extracted/label_1/right_49.png
# Panorama:  TMX7316010203-002950_pano_0001_000216 LR:  left Label:  0
# File path:  res/dataset/centrum_west_full/masked_extracted/label_0/left_50.png
# Panorama:  TMX7316010203-002950_pano_0001_000216 LR:  right Label:  1
# File path:  res/dataset/centrum_west_full/masked_extracted/label_1/right_51.png
# Panorama:  TMX7316010203-002861_pano_0001_000081 LR:  left Label:  2
# File path:  res/dataset/centrum_west_full/masked_extracted/label_2/left_52.png
# Panorama:  TMX7316010203-002861_pano_0001_000081 LR:  right Label:  1
# File path:  res/dataset/centrum_west_full/masked_extracted/label_1/right_53.png
# Panorama:  TMX7316010203-002532_pano_0000_000293 LR:  left Label:  0
# File path:  res/dataset/centrum_west_full/masked_extracted/label_0/left_54.png
# Panorama:  TMX7316010203-002532_pano_0000_000293 LR:  right Label:  0
# File path:  res/dataset/centrum_west_full/masked_extracted/label_0/right_55.png
# Panorama:  TMX7316010203-002037_pano_0001_000188 LR:  left Label:  0
# File path:  res/dataset/centrum_west_full/masked_extracted/label_0/left_56.png
# Panorama:  TMX7316010203-002037_pano_0001_000188 LR:  right Label:  4
# File path:  res/dataset/centrum_west_full/masked_extracted/label_4/right_57.png
# Panorama:  TMX7316010203-002037_pano_0001_000134 LR:  left Label:  5
# File path:  res/dataset/centrum_west_full/masked_extracted/label_5/left_58.png
# Panorama:  TMX7316010203-002037_pano_0001_000134 LR:  right Label:  4
# File path:  res/dataset/centrum_west_full/masked_extracted/label_4/right_59.png
